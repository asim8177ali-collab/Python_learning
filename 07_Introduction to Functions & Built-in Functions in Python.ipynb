# %% [markdown]
# # **Lecture: Introduction to Functions & Built-in Functions in Python**
#
# ## 📝 **Topics Covered**
# In this lecture, we will explore:
# 1. **What are Functions?** – Understanding what functions are and how they help in programming.
# 2. **Why Use Functions?** – The need for functions and their benefits.
# 3. **Types of Functions in Python** – Exploring different types of functions.
# 4. **Built-in Functions in Python** – Introduction to functions that are already available in Python.

# %% [markdown]
# ## **What are Functions?**
# A **function** is a reusable block of code designed to perform a specific task. Instead of writing the same code multiple times, we can define a function once and use it whenever needed.
#
# Functions help break down a large program into smaller, manageable parts, making it easier to read, debug, and maintain.
#
# When a function is called, it runs the set of instructions inside it and can return a result if needed.

# %% [markdown]
# ## **Hard to Understand? Let’s Use a Real-World Example!**
# Think of a function like a **recipe in a restaurant**. Let’s break it down:
#
# 1. Imagine you are in a restaurant, and every time a customer orders a dish, the chef follows a **fixed recipe** to prepare it.
# 2. Instead of writing down the steps **every time** an order is placed, the chef just **refers to the recipe**, making the process **faster and more efficient**.
# 3. In Python, a **function** works just like a recipe – it is a **set of instructions** that performs a specific task whenever needed.
# 4. Once a function (recipe) is defined, you can **reuse** it multiple times without repeating the steps, just like the chef making the same dish again and again.
# 5. If you ever need to make small changes to a dish, you can **modify the recipe** instead of rewriting the whole thing – this is like **updating a function** to improve or extend its behavior.
# 6. Functions **save time, reduce errors, and keep the code organized**, just like recipes make cooking more efficient in a busy restaurant!
#
# **In programming, functions help us write clean, efficient, and reusable code. Just like a chef doesn’t need to remember every dish’s steps from scratch, we don’t need to rewrite code every time – we just call the function!**

# %% [markdown]
# ## **Why Use Functions?**
# Just like in a restaurant, where recipes help chefs work **faster and more efficiently**, functions help programmers write **cleaner and reusable** code.
#
# ### **✔️ Benefits of Functions (Using Our Restaurant Analogy)**
# - **Avoids Repetition** – Instead of writing the same steps repeatedly, we create a function (recipe) once and reuse it.
# - **Modular & Organized** – Just like restaurants have different recipes for different dishes, programs have functions for different tasks.
# - **Improves Readability & Debugging** – If there’s an issue with a dish, the chef fixes the recipe instead of checking every single order. Similarly, debugging is easier with functions.
# - **Code Reusability** – A restaurant doesn’t rewrite the recipe for every new customer; it just follows the same process. Likewise, we can reuse functions instead of rewriting code.
# - **Enhances Collaboration** – Different chefs can prepare different dishes simultaneously, just as developers can work on different functions in a program.

# %% [markdown]
# ## **Types of Functions in Python**
# Just like restaurants have different types of recipes (for main courses, desserts, and drinks), Python has different types of functions:
#
# 1. **Built-in Functions** – These are pre-defined functions that come with Python, like ready-made recipes that chefs can use immediately.
# 2. **User-defined Functions** – These are functions created by the programmer, like a chef inventing a new dish for the menu.

# %% [markdown]
# # **Demonstrating Built-in Functions in Python**
# Now that we understand what functions are and why they are useful, let’s explore **built-in functions** in Python.
#
# Built-in functions are like the **ready-made sauces and ingredients** available in a restaurant. Instead of making them from scratch, the chef can **use them directly** to speed up the cooking process. Similarly, Python provides many built-in functions that help us perform common tasks **without writing extra code**.
#
# Let's try out some of these built-in functions!

# %%
# The print() function Displays output (like a waiter serving food). 

print("Welcome to Python Functions!")
# Out:
# Welcome to Python Functions!

# %%
# The input() function takes user input (like a waiter taking an order).
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# Hello, Haris

# %%
# The type() function returns the type of a variable (like checking if an ingredient is fresh or expired).  

num = 10
print("The type of num is:", type(num))
# Out:
# The type of num is: <class 'int'>

# %%
# The len() function returns the length of an object (like counting the number of ingredients in a dish).  

word = "Python"
print("The length of the word is:", len(word))
# Out:
# The length of the word is: 6

# %%
# The max() function returns the largest value from a list of numbers (like a restaurant owner checking which dish has the highest price on the menu, max() helps find the largest value in a list).

prices = [10, 25, 8, 15, 30]
highest_price = max(prices)
print("The highest price on the menu is:", highest_price)
# Out:
# The highest price on the menu is: 30

# %%
# The sorted() function sorts a list in ascending order by default (like arranging dishes in a menu from lowest to highest price).

ratings = [4.5, 3.9, 5.0, 4.2, 4.8]
sorted_ratings = sorted(ratings)            #[::-1] for highest to lowest
print("The restaurant ratings from lowest to highest:", sorted_ratings)
# Out:
# The restaurant ratings from lowest to highest: [3.9, 4.2, 4.5, 4.8, 5.0]

# %%
# Generates a sequence of numbers (like preparing a set number of meals for a buffet).

for i in range(1,6):
    print("Dish", i, "is ready!")
# Out:
# Dish 1 is ready!
# Dish 2 is ready!
# Dish 3 is ready!
# Dish 4 is ready!
# Dish 5 is ready!

# %%
# Returns the memory address of an object (like labeling dishes with order numbers).  

x = 42
print("The memory address of x is:", id(x))
# Out:
# The memory address of x is: 1775180776976

# %%
# Evaluates expressions (like calculating the bill at the end of a meal). 

expression = "5 + 3 * 2"
result = eval(expression)
print("The result of the expression is:", result)
# Out:
# The result of the expression is: 11

# %% [markdown]
# ## 💻 Exercises ➞ <span class='label label-default'>Built-in Functions</span>
#
# Now that you've learned about Python's built-in functions, try solving the following exercises to test your understanding!
#
# ---
#
# ### **1️⃣ Find the Longest Word**
# Write a program that takes a list of words and uses a **built-in function** to find and print the **longest word**.
#
# 🔹 **Example Input:**
# `words = ["Python", "Programming", "Code", "Functions"]`
#
# 🔹 **Expected Output:**
# `The longest word is: Programming`
#
# ---
#
# ### **2️⃣ Count the Vowels**
# Write a program that takes a **sentence** as input and uses a built-in function to count the number of **vowels (a, e, i, o, u)** in it.
#
# 🔹 **Example Input:**
# `sentence = "Functions make coding easier"`
#
# 🔹 **Expected Output:**
# `Number of vowels: 10`
#
# ---
#
# ### **3️⃣ Find the Largest Number**
# Write a program that asks the user to enter **five numbers**, stores them in a list, and then finds the **largest number** using a built-in function.
#
# 🔹 **Example Input:**
# `numbers = [12, 45, 67, 23, 89]`
#
# 🔹 **Expected Output:**
# `The largest number is: 89`
#
# ---
#
# ### **4️⃣ Sort Prices in Descending Order**
# Write a program that takes a list of **food prices** from a restaurant menu and **sorts them from highest to lowest** using a built-in function.
#
# 🔹 **Example Input:**
# `prices = [15, 40, 10, 25, 30]`
#
# 🔹 **Expected Output:**
# `Sorted prices (high to low): [40, 30, 25, 15, 10]`
#
# ---
#
# ✅ **Try these exercises and test your understanding of Python's built-in functions!**

# %% [markdown]
# # **practice**

# %%
# # 01 find longest word 
# words = ["Python", "Programming", "Code", "Functions"]        # longest word from list of words.
# sentence="Artificial intelligence will transform the world"
# words= sentence.split()                 # sentence longest word
# longest_word= max(words, key=len)       #key=len tells python work on the lenght of words 
# print(f"Longest word in the list is '{longest_word}'")



# # 02 count number of vowels
# sentence = "Functions make coding easier"
# vowels="aeiou"
# vowel_counter= sum(1 for char in sentence.lower() if char in vowels)
# print(f"Number vowels in this sentence is {vowel_counter}.")



# # 03 fing largest number
# numbers = [123, 45, 67, 23, 89]
# largest_num= max(numbers)
# print(f"Largest number is: {largest_num}.")



# # 04 sort prices in descending order.
# prices = [15, 40, 10, 25, 30, 13, 54, 143, 523, 523424, 5234, 52352323, 5664635,363639430]
# descend_prices= sorted(prices)[::-1]
# print(f"Prices in descending order: {descend_prices}")



# # 05 print len and type.
# name="Asim"
# numbers=[10, 43, 53, 12, 534, 54]
# fruit_list= ["apple", "mango", "banana", "pineapple", "orange"]
# print("\nUse of print(), len(), type() function.")
# print(len(name))
# print(len(numbers))
# print(len(fruit_list))
# print(type(name))
# print(type(numbers))
# print(type(fruit_list))



# # 06 use of min max sum and abs()
# numbers=[10, 43, 53, 12, 534, 54]
# tempreture_list= [33, 15, -4, 40, 50]
# print("\nUse of min(), max(), sum() and abs()/absolute functions.")
# print(f"Maximun number from list: {max(numbers)}")
# print(f"Smallest number from list: {min(numbers)}")
# print(f"Sum of all numbers from list: {sum(numbers)}")
# print(f"Converting negetive numbers to positive numbers: {abs(-34)}")  # only one number at a time
# print("\nTempreture calculations.")
# print(f"{max(tempreture_list)}' is the hottest day.")
# print(f"{min(tempreture_list)}' is the coldest day.")
# print(f"{sum(tempreture_list)/len(tempreture_list)}' is the average day.")

print("------------------------------------------------")

# # 07 use of range() enumerate() and zip()
# for index, i in enumerate(range(1, 11)):
#     print(f"{index+1}: I am the best.")

# students=["Sare", "Hassan", "Ali", "Mudassir"]
# students_marks=[80, 98.5, 100, 67]

# print("\nZip use.")
# for name, marks in zip(students, students_marks):
#     print(f"{name} has {marks} marks.")

# crop_list=["wheat", "sugarcane", "bersame", "joo"]
# harvest_time=["Nov-May", "Feb-Jan or Sep-Dec", "Oct-April", "April-Nov"]
# print("Harvest time.\n")
# for crop, harvest_time in zip(crop_list, harvest_time):
#     print(f"{crop} is harvested between {harvest_time}.")

print("------------------------------------------------")

# # 08 sorted, reverse and round
# numbers_list=[34, 5243, 45, -343, 32, -1345]
# print(f"\nLowest to highest number: {sorted(numbers_list)}")
# print(f"Rounding a number to 2 decimal places: {round(2344.43214, 2)}") 
# print(f"Rounding a number to 2 decimal places: {2344.43214:.2f} manually.") # manual way
# print(f"Reversing a list from high to low: {sorted(numbers_list, reverse=True)}")
# print(f"Reversing a list from high to low: {sorted(numbers_list)[::-1]} manually.\n") # manually

print("------------------------------------------------")

# # 09 use of map() and filter()
# # map is used to apply a single function to multiple values or arguments
# #filter() is used to get or keep things according to a condition 
# numbers_list=[1,2,4,3,5,6,7,8,9,10]
# wheat_yeild=[30, 55, 20, 70, 45]
# print(f"Square of values: {list(map(lambda x: x**2, numbers_list))}")
# print(f"Filter divisible's of 2: {list(filter(lambda x: x%2==0, numbers_list))}\n")
# yeild_40=list(filter(lambda x: x>40, wheat_yeild))
# print(f"Filtering yeild above 40: {len(yeild_40)} fields have yeild above 40 {yeild_40} ")

print("------------------------------------------------")

# 10 conbining above all functions
students = ["Asim", "Ali", "Sara", "Zara"]
grades = [95, 99.5, 88, 60]

# find topper
top_grades= grades.index(max(grades))
print(f"Topper of class is {students[top_grades]} with {grades[top_grades]} marks.")

for rank, (student, grade) in enumerate(zip(students, grades),1):
    print(f"Rank {rank}: {student} -- {grade}.")
# Out:
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
# Topper of class is Ali with 99.5 marks.
# Rank 1: Asim -- 95.
# Rank 2: Ali -- 99.5.
# Rank 3: Sara -- 88.
# Rank 4: Zara -- 60.

# %%
# built in functions challenges

#01 studnet Grade analyzer
students = ["Asim", "Ali", "Sara", "Zara", "Bilal"]
scores =   [88.593,   72.233,  91.307,   55.2,   67.08]

#rounding numbers to 1 decimal place
rounded_score= list(map(lambda score: round(score,1), scores)) and [round(score,1) for score in scores] # both ways are good and work here i use and operator to check if bith are working or not

# filter student above or = to 70
# zip_students= 
above_70= list(filter(lambda student: student[1]>=70 ,zip(students, scores)))
sorted_above_70= sorted(above_70, reverse=True)
for index ,(name,score) in enumerate(sorted_above_70):
    print(f"{index+1}. {name} - {score} ✅.")
# Out:
# 1. Sara - 91.307 ✅.
# 2. Asim - 88.593 ✅.
# 3. Ali - 72.233 ✅.
